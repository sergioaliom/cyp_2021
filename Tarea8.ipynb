# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioaliom/cyp_2021/blob/main/Tarea8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\u250c\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2510")
print("\u2502\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u2502")
print("\u2502\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u2502")
print("\u2502\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u2502")
print("\u2502\u0020\u0020\u0020\u2700\u2700\u2700\u2700\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u2502")
print("\u2502\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u2502")
print("\u2502\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u2700\u2700\u2700\u2700\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u0020\u2700\u0020\u0020\u2502")
print("\u2514\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2500\u2519")
# Out:
# ┌───────────────────────────────────────────┐
# │      ✀             ✀               ✀   │
# │     ✀ ✀           ✀               ✀   │
# │    ✀   ✀          ✀               ✀   │
# │   ✀✀✀✀✀        ✀                ✀  │
# │  ✀       ✀       ✀                ✀   │
# │ ✀         ✀      ✀✀✀✀✀         ✀  │
# └──────────────────────────────────────────┙
